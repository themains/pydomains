# %%
from __future__ import print_function
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import numpy as np
import tensorflow as tf
import pandas as pd

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

np.random.seed(1)
tf.random.set_seed(2)

NGRAMS = 2
FEATURE_LEN = 128
EPOCHS = 15
SAMPLES = 50000

df = pd.read_csv('../train-test/data/phishtank_2017.csv.bz2')
df.dropna(subset=['domain'], inplace=True)
df
# Out:
# Using TensorFlow backend.
#              ID                                          Phish URL  \
# 0       4717300  http://g28.ycxafz.biz/added on Jan 1st 2017 6:...
# 1       4717281  http://sistemas.miranda.gob.ve/1/Sign%20on/add...
# 2       4717246  http://sheehydaringproject.com/PDFILES/added o...
# 3       4717232  http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       4717222  http://www.w-reia.com/bremer/new.php?cmd=login...
# ...         ...                                                ...
# 101315  5407512  http://posari.com/Goody/Yahoo/home/index.phpad...
# 101316  5407505  http://abrazzak.com/login.php?cmd=login_submit...
# 101317  5407493  http://khanqahzakariya.lk/wpadmin/ex2017/login...
# 101318  5407490  http://pegesunblocking.000webhostapp.com/bayar...
# 101319  5407489  http://pegesunblocking.000webhostapp.com/bayar...
#
#          Submitted       Valid?  Online?  \
# 0       by cleanmx  VALID PHISH  Offline
# 1       by cleanmx  VALID PHISH  Offline
# 2       by cleanmx  VALID PHISH  Offline
# 3       by cleanmx  VALID PHISH  Offline
# 4       by cleanmx  VALID PHISH  Offline
# ...            ...          ...      ...
# 101315  by cleanmx  VALID PHISH  Offline
# 101316  by cleanmx  VALID PHISH   ONLINE
# 101317  by cleanmx  VALID PHISH   ONLINE
# 101318  by cleanmx  VALID PHISH  Offline
# 101319  by cleanmx  VALID PHISH  Offline
#
#                                                       url  \
# 0                                  http://g28.ycxafz.biz/
# 1             http://sistemas.miranda.gob.ve/1/Sign%20on/
# 2                 http://sheehydaringproject.com/PDFILES/
# 3       http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       http://www.w-reia.com/bremer/new.php?cmd=login...
# ...                                                   ...
# 101315       http://posari.com/Goody/Yahoo/home/index.php
# 101316  http://abrazzak.com/login.php?cmd=login_submit...
# 101317  http://khanqahzakariya.lk/wpadmin/ex2017/login...
# 101318  http://pegesunblocking.000webhostapp.com/bayar...
# 101319  http://pegesunblocking.000webhostapp.com/bayar...
#
#                        date                             domain
# 0       2017-01-01 06:45:00                     g28.ycxafz.biz
# 1       2017-01-01 05:46:00            sistemas.miranda.gob.ve
# 2       2017-01-01 04:15:00            sheehydaringproject.com
# 3       2017-01-01 03:15:00                    monar-kielce.pl
# 4       2017-01-01 02:46:00                     www.w-reia.com
# ...                     ...                                ...
# 101315  2018-01-01 05:42:00                         posari.com
# 101316  2018-01-01 05:41:00                       abrazzak.com
# 101317  2018-01-01 05:41:00                 khanqahzakariya.lk
# 101318  2018-01-01 05:40:00  pegesunblocking.000webhostapp.com
# 101319  2018-01-01 05:40:00  pegesunblocking.000webhostapp.com
#
# [101320 rows x 8 columns]

# %%
sdf = df.drop_duplicates('domain')
sdf
# Out:
#              ID                                          Phish URL  \
# 0       4717300  http://g28.ycxafz.biz/added on Jan 1st 2017 6:...
# 1       4717281  http://sistemas.miranda.gob.ve/1/Sign%20on/add...
# 2       4717246  http://sheehydaringproject.com/PDFILES/added o...
# 3       4717232  http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       4717222  http://www.w-reia.com/bremer/new.php?cmd=login...
# ...         ...                                                ...
# 101289  5407454  http://online-banking.mobile.go.mambanetworkso...
# 101291  5407450  http://www.royalbankpacific.com/wp-admin/maint...
# 101293  5407446  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101300  5407544  http://camplakefire.com.au/include/chase-onlin...
# 101301  5407543  http://assemblgroup.com/ww/8eef918ed75a259d0e3...
#
#          Submitted       Valid?  Online?  \
# 0       by cleanmx  VALID PHISH  Offline
# 1       by cleanmx  VALID PHISH  Offline
# 2       by cleanmx  VALID PHISH  Offline
# 3       by cleanmx  VALID PHISH  Offline
# 4       by cleanmx  VALID PHISH  Offline
# ...            ...          ...      ...
# 101289  by cleanmx  VALID PHISH  Offline
# 101291  by cleanmx  VALID PHISH  Offline
# 101293  by cleanmx  VALID PHISH  Offline
# 101300  by cleanmx  VALID PHISH  Offline
# 101301  by cleanmx  VALID PHISH  Offline
#
#                                                       url  \
# 0                                  http://g28.ycxafz.biz/
# 1             http://sistemas.miranda.gob.ve/1/Sign%20on/
# 2                 http://sheehydaringproject.com/PDFILES/
# 3       http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       http://www.w-reia.com/bremer/new.php?cmd=login...
# ...                                                   ...
# 101289  http://online-banking.mobile.go.mambanetworkso...
# 101291  http://www.royalbankpacific.com/wp-admin/maint...
# 101293  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101300  http://camplakefire.com.au/include/chase-onlin...
# 101301  http://assemblgroup.com/ww/8eef918ed75a259d0e3...
#
#                        date                                             domain
# 0       2017-01-01 06:45:00                                     g28.ycxafz.biz
# 1       2017-01-01 05:46:00                            sistemas.miranda.gob.ve
# 2       2017-01-01 04:15:00                            sheehydaringproject.com
# 3       2017-01-01 03:15:00                                    monar-kielce.pl
# 4       2017-01-01 02:46:00                                     www.w-reia.com
# ...                     ...                                                ...
# 101289  2018-01-01 04:41:00  online-banking.mobile.go.mambanetworksolutions...
# 101291  2018-01-01 04:40:00                           www.royalbankpacific.com
# 101293  2018-01-01 04:40:00                            healthyidealroutine.com
# 101300  2018-01-01 07:10:00                                camplakefire.com.au
# 101301  2018-01-01 07:10:00                                   assemblgroup.com
#
# [56517 rows x 8 columns]

# %%
try:
    sdf.groupby('target').agg({'domain': 'count'})
except:
    pass

# %%
adf = pd.read_csv('../train-test/data/top-1m.csv.zip', header=None)
adf.columns = ['rank', 'domain']
adf
# Out:
#            rank               domain
# 0             1           google.com
# 1             2          youtube.com
# 2             3         facebook.com
# 3             4            baidu.com
# 4             5        wikipedia.org
# ...         ...                  ...
# 999995   999996  liberty-shopping.us
# 999996   999997              uazz.pl
# 999997   999998        waltonsun.com
# 999998   999999             aspvv.it
# 999999  1000000       wetterklima.de
#
# [1000000 rows x 2 columns]

# %%
ldf = adf[['domain']].head(SAMPLES)
pdf = sdf[['domain']].sample(SAMPLES, random_state=21)

# %%
ldf['phishing'] = False
pdf['phishing'] = True
tdf = pd.concat([ldf, pdf])
tdf
# Out:
#                                        domain  phishing
# 0                                  google.com     False
# 1                                 youtube.com     False
# 2                                facebook.com     False
# 3                                   baidu.com     False
# 4                               wikipedia.org     False
# ...                                       ...       ...
# 25900  unlocklivevideofacebook.lifecares.info      True
# 28584                              co.digital      True
# 86481                        alexggilbert.com      True
# 13097                            www.union.gr      True
# 8418                       simunpetshop.co.id      True
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Preprocessing the input data

# %%
if True:
    # build n-gram list
    vect = CountVectorizer(analyzer='char', max_df=0.3, min_df=3, ngram_range=(NGRAMS, NGRAMS), lowercase=False) 
    #vect = CountVectorizer(analyzer='char', ngram_range=(NGRAMS, NGRAMS), lowercase=False) 
    a = vect.fit_transform(tdf.domain)
    vocab = vect.vocabulary_

    # sort n-gram by freq (highest -> lowest)
    words = []
    for b in vocab:
        c = vocab[b]
        #print(b, c, a[:, c].sum())
        words.append((a[:, c].sum(), b))
        #break
    words = sorted(words, reverse=True)
    words_list = [w[1] for w in words]
    num_words = len(words_list)
    print("num_words = %d" % num_words)


    def find_ngrams(text, n):
        a = zip(*[text[i:] for i in range(n)])
        wi = []
        for i in a:
            w = ''.join(i)
            try:
                idx = words_list.index(w)
            except:
                idx = 0
            wi.append(idx)
        return wi

    # build X from index of n-gram sequence
    X = np.array(tdf.domain.apply(lambda c: find_ngrams(c, NGRAMS)))
else:
    data = tdf.domain.str.cat()
    chars = list(set(data))
    data_size, vocab_size = len(data), len(chars)
    print('data has %d characters, %d unique.' % (data_size, vocab_size))
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }
    num_words = vocab_size
    X = np.array(tdf.domain.apply(lambda c: [char_to_ix[a] for a in c]))
X
# Out:
# num_words = 1453
# array([list([129, 105, 134, 311, 39, 8, 0, 0, 0]),
#        list([288, 68, 141, 166, 213, 128, 8, 0, 0, 0]),
#        list([188, 43, 66, 58, 161, 105, 218, 142, 0, 0, 0]), ...,
#        list([16, 39, 219, 894, 471, 152, 77, 376, 128, 3, 76, 25, 0, 0, 0]),
#        list([1, 1, 15, 146, 83, 102, 60, 9, 36, 154, 182]),
#        list([65, 149, 290, 83, 367, 121, 13, 137, 133, 38, 157, 74, 0, 0, 28, 46, 103])],
#       dtype=object)

# %%
# check max/avg feature
X_len = []
for x in X:
    X_len.append(len(x))

max_feature_len = max(X_len)
avg_feature_len = int(np.mean(X_len))

print("Max feature len = %d, Avg. feature len = %d" % (max_feature_len, avg_feature_len))
# Out:
# Max feature len = 62, Avg. feature len = 16

# %%
y = np.array(tdf.phishing.astype('category').cat.codes)

# Split train and test dataset
X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %% [markdown]
# ## Train a LSTM model

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, Activation
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import load_model

max_features = num_words # 20000
feature_len = FEATURE_LEN # avg_feature_len # cut texts after this number of words (among top max_features most common words)
batch_size = 32

print(len(X_train), 'train sequences')
print(len(X_test), 'test sequences')

print('Pad sequences (samples x time)')
X_train = sequence.pad_sequences(X_train, maxlen=feature_len)
X_test = sequence.pad_sequences(X_test, maxlen=feature_len)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
# Out:
# 80000 train sequences
# 20000 test sequences
# Pad sequences (samples x time)
# X_train shape: (80000, 128)
# X_test shape: (20000, 128)

# %%
# Function to create model, required for KerasClassifier
def create_model():
    print('Build model...')

    model = Sequential()
    model.add(Embedding(num_words, 32, input_length=feature_len))
    model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))

    # try using different optimizers and different optimizer configs
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    #print(model.summary())
    return model

# %% [raw]
# print('Train...')
# model.fit(X_train, y_train, batch_size=batch_size, epochs=EPOCHS,
#           validation_split=0.1, verbose=1)
# score, acc = model.evaluate(X_test, y_test,
#                             batch_size=batch_size, verbose=1)
# print('Test score:', score)
# print('Test accuracy:', acc)

# %%
import matplotlib.pyplot as plt

from sklearn.calibration import CalibratedClassifierCV, calibration_curve
from sklearn.metrics import (brier_score_loss, precision_score, recall_score,
                             f1_score)
from sklearn.linear_model import LogisticRegression

model = KerasClassifier(build_fn=create_model, epochs=EPOCHS, batch_size=batch_size, verbose=1)

# %%
def plot_calibration_curve(est, name, fig_index):
    """Plot calibration curve for est w/o and with calibration. """
    # Calibrated with isotonic calibration
    isotonic = CalibratedClassifierCV(est, cv=2, method='isotonic')

    # Calibrated with sigmoid calibration
    sigmoid = CalibratedClassifierCV(est, cv=2, method='sigmoid')

    # Logistic regression with no calibration as baseline
    lr = LogisticRegression(C=1.)

    fig = plt.figure(fig_index, figsize=(10, 10))
    ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
    ax2 = plt.subplot2grid((3, 1), (2, 0))

    ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    for clf, name in [(lr, 'Logistic'),
                      (est, name),
                      (isotonic, name + ' + Isotonic'),
                      (sigmoid, name + ' + Sigmoid')]:
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        if hasattr(clf, "predict_proba"):
            prob_pos = clf.predict_proba(X_test)[:, 1]
        else:  # use decision function
            prob_pos = clf.decision_function(X_test)
            prob_pos = \
                (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())

        clf_score = brier_score_loss(y_test, prob_pos, pos_label=y.max())
        print("%s:" % name)
        print("\tBrier: %1.3f" % (clf_score))
        print("\tPrecision: %1.3f" % precision_score(y_test, y_pred))
        print("\tRecall: %1.3f" % recall_score(y_test, y_pred))
        print("\tF1: %1.3f\n" % f1_score(y_test, y_pred))

        fraction_of_positives, mean_predicted_value = \
            calibration_curve(y_test, prob_pos, n_bins=10)

        ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
                 label="%s (%1.3f)" % (name, clf_score))

        ax2.hist(prob_pos, range=(0, 1), bins=10, label=name,
                 histtype="step", lw=2)

    ax1.set_ylabel("Fraction of positives")
    ax1.set_ylim([-0.05, 1.05])
    ax1.legend(loc="lower right")
    ax1.set_title('Calibration plots  (reliability curve)')

    ax2.set_xlabel("Mean predicted value")
    ax2.set_ylabel("Count")
    ax2.legend(loc="upper center", ncol=2)

    plt.tight_layout()

# Plot calibration curve for LSTM
plot_calibration_curve(model, "LSTM", 1)

plt.show()
# Out:
# Logistic:
# 	Brier: 0.183
# 	Precision: 0.794
# 	Recall: 0.631
# 	F1: 0.703
#
# Build model...
# Epoch 1/15
# 80000/80000 [==============================] - 489s 6ms/step - loss: 0.4040 - accuracy: 0.8090
# Epoch 2/15
# 80000/80000 [==============================] - 485s 6ms/step - loss: 0.3733 - accuracy: 0.8255
# Epoch 3/15
# 80000/80000 [==============================] - 489s 6ms/step - loss: 0.3600 - accuracy: 0.8326
# Epoch 4/15
# 80000/80000 [==============================] - 488s 6ms/step - loss: 0.3528 - accuracy: 0.8352
# Epoch 5/15
# 80000/80000 [==============================] - 487s 6ms/step - loss: 0.3480 - accuracy: 0.83813s
# Epoch 6/15
# 80000/80000 [==============================] - 489s 6ms/step - loss: 0.3401 - accuracy: 0.8418
# Epoch 7/15
# 80000/80000 [==============================] - 497s 6ms/step - loss: 0.3353 - accuracy: 0.8443
# Epoch 8/15
# 80000/80000 [==============================] - 496s 6ms/step - loss: 0.3307 - accuracy: 0.8464
# Epoch 9/15
# 80000/80000 [==============================] - 494s 6ms/step - loss: 0.3287 - accuracy: 0.8483
# Epoch 10/15
# 80000/80000 [==============================] - 489s 6ms/step - loss: 0.3227 - accuracy: 0.8517
# Epoch 11/15
# 80000/80000 [==============================] - 488s 6ms/step - loss: 0.3195 - accuracy: 0.8529
# Epoch 12/15
# 80000/80000 [==============================] - 491s 6ms/step - loss: 0.3167 - accuracy: 0.8535
# Epoch 13/15
# 80000/80000 [==============================] - 492s 6ms/step - loss: 0.3125 - accuracy: 0.8575
# Epoch 14/15
# 80000/80000 [==============================] - 496s 6ms/step - loss: 0.3100 - accuracy: 0.8575
# Epoch 15/15
# 80000/80000 [==============================] - 494s 6ms/step - loss: 0.3054 - accuracy: 0.8599
# 20000/20000 [==============================] - 33s 2ms/step
# 20000/20000 [==============================] - 33s 2ms/step
# LSTM:
# 	Brier: 0.115
# 	Precision: 0.893
# 	Recall: 0.766
# 	F1: 0.824
#
# Build model...
# Epoch 1/15
# 40000/40000 [==============================] - 249s 6ms/step - loss: 0.4199 - accuracy: 0.8006
# Epoch 2/15
# 40000/40000 [==============================] - 248s 6ms/step - loss: 0.3779 - accuracy: 0.8216
# Epoch 3/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3639 - accuracy: 0.8309
# Epoch 4/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3605 - accuracy: 0.8320
# Epoch 5/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3499 - accuracy: 0.8371
# Epoch 6/15
# 40000/40000 [==============================] - 246s 6ms/step - loss: 0.3428 - accuracy: 0.8396
# Epoch 7/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3368 - accuracy: 0.8436
# Epoch 8/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3323 - accuracy: 0.8469
# Epoch 9/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3267 - accuracy: 0.8481
# Epoch 10/15
# 40000/40000 [==============================] - 246s 6ms/step - loss: 0.3246 - accuracy: 0.8494
# Epoch 11/15
# 40000/40000 [==============================] - 246s 6ms/step - loss: 0.3171 - accuracy: 0.8539
# Epoch 12/15
# 40000/40000 [==============================] - 245s 6ms/step - loss: 0.3134 - accuracy: 0.8556
# Epoch 13/15
# 40000/40000 [==============================] - 246s 6ms/step - loss: 0.3098 - accuracy: 0.8576
# Epoch 14/15
# 40000/40000 [==============================] - 246s 6ms/step - loss: 0.3084 - accuracy: 0.8568
# Epoch 15/15
# 40000/40000 [==============================] - 249s 6ms/step - loss: 0.3052 - accuracy: 0.8589
# 40000/40000 [==============================] - 67s 2ms/step
# Build model...
# Epoch 1/15
# 40000/40000 [==============================] - 253s 6ms/step - loss: 0.4212 - accuracy: 0.8003
# Epoch 2/15
# 40000/40000 [==============================] - 251s 6ms/step - loss: 0.3780 - accuracy: 0.8250
# Epoch 3/15
# 40000/40000 [==============================] - 251s 6ms/step - loss: 0.3675 - accuracy: 0.8280
# Epoch 4/15
# 40000/40000 [==============================] - 249s 6ms/step - loss: 0.3588 - accuracy: 0.8329
# Epoch 5/15
# 40000/40000 [==============================] - 248s 6ms/step - loss: 0.3530 - accuracy: 0.8363
# Epoch 6/15
# 40000/40000 [==============================] - 254s 6ms/step - loss: 0.3466 - accuracy: 0.8389
# Epoch 7/15
# 40000/40000 [==============================] - 197s 5ms/step - loss: 0.3436 - accuracy: 0.8399
# Epoch 8/15
# 40000/40000 [==============================] - 177s 4ms/step - loss: 0.3574 - accuracy: 0.8325
# Epoch 9/15
# 40000/40000 [==============================] - 177s 4ms/step - loss: 0.3371 - accuracy: 0.8431
# Epoch 10/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3312 - accuracy: 0.8456
# Epoch 11/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3258 - accuracy: 0.8491
# Epoch 12/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3201 - accuracy: 0.8521
# Epoch 13/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3173 - accuracy: 0.8533
# Epoch 14/15
# 40000/40000 [==============================] - 184s 5ms/step - loss: 0.3142 - accuracy: 0.8567
# Epoch 15/15
# 40000/40000 [==============================] - 186s 5ms/step - loss: 0.3088 - accuracy: 0.8579
# 40000/40000 [==============================] - 59s 1ms/step
# 20000/20000 [==============================] - 29s 1ms/step
# 20000/20000 [==============================] - 30s 2ms/step
# 20000/20000 [==============================] - 30s 1ms/step
# 20000/20000 [==============================] - 28s 1ms/step
# LSTM + Isotonic:
# 	Brier: 0.118
# 	Precision: 0.883
# 	Recall: 0.766
# 	F1: 0.820
#
# Build model...
# Epoch 1/15
# 40000/40000 [==============================] - 180s 4ms/step - loss: 0.4182 - accuracy: 0.8007
# Epoch 2/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3751 - accuracy: 0.8242
# Epoch 3/15
# 40000/40000 [==============================] - 180s 5ms/step - loss: 0.3662 - accuracy: 0.8283
# Epoch 4/15
# 40000/40000 [==============================] - 195s 5ms/step - loss: 0.3581 - accuracy: 0.8340
# Epoch 5/15
# 40000/40000 [==============================] - 189s 5ms/step - loss: 0.3511 - accuracy: 0.8377
# Epoch 6/15
# 40000/40000 [==============================] - 186s 5ms/step - loss: 0.3447 - accuracy: 0.8394
# Epoch 7/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3413 - accuracy: 0.8425
# Epoch 8/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3424 - accuracy: 0.8416
# Epoch 9/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3303 - accuracy: 0.8463
# Epoch 10/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3278 - accuracy: 0.8481
# Epoch 11/15
# 40000/40000 [==============================] - 180s 4ms/step - loss: 0.3220 - accuracy: 0.8504
# Epoch 12/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3183 - accuracy: 0.8542
# Epoch 13/15
# 40000/40000 [==============================] - 179s 4ms/step - loss: 0.3145 - accuracy: 0.8542
# Epoch 14/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3107 - accuracy: 0.8583
# Epoch 15/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3062 - accuracy: 0.8585
# 40000/40000 [==============================] - 52s 1ms/step
# Build model...
# Epoch 1/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.4211 - accuracy: 0.7995
# Epoch 2/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3801 - accuracy: 0.8227
# Epoch 3/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3671 - accuracy: 0.8293
# Epoch 4/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3591 - accuracy: 0.8340
# Epoch 5/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3516 - accuracy: 0.8370
# Epoch 6/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3464 - accuracy: 0.8388
# Epoch 7/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3406 - accuracy: 0.8410
# Epoch 8/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3350 - accuracy: 0.8436
# Epoch 9/15
# 40000/40000 [==============================] - 177s 4ms/step - loss: 0.3291 - accuracy: 0.8498
# Epoch 10/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3391 - accuracy: 0.8443
# Epoch 11/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3313 - accuracy: 0.8475
# Epoch 12/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3243 - accuracy: 0.8516
# Epoch 13/15
# 40000/40000 [==============================] - 178s 4ms/step - loss: 0.3216 - accuracy: 0.8515
# Epoch 14/15
# 40000/40000 [==============================] - 175s 4ms/step - loss: 0.3155 - accuracy: 0.8557
# Epoch 15/15
# 40000/40000 [==============================] - 176s 4ms/step - loss: 0.3102 - accuracy: 0.8556
# 40000/40000 [==============================] - 53s 1ms/step
# 20000/20000 [==============================] - 27s 1ms/step
# 20000/20000 [==============================] - 27s 1ms/step
# 20000/20000 [==============================] - 26s 1ms/step
# 20000/20000 [==============================] - 26s 1ms/step
# LSTM + Sigmoid:
# 	Brier: 0.118
# 	Precision: 0.861
# 	Recall: 0.791
# 	F1: 0.825

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred = model.predict(X_test, verbose=1)
y_probs = model.predict_proba(X_test, verbose=1) # to predict probability
target_names = list(tdf.phishing.astype('category').cat.categories)
# Out:
# 20000/20000 [==============================] - 27s 1ms/step
# 20000/20000 [==============================] - 26s 1ms/step

# %%
target_names = [str(t) for t in target_names]
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.80      0.91      0.85     10000
#         True       0.89      0.77      0.82     10000
#
#     accuracy                           0.84     20000
#    macro avg       0.84      0.84      0.84     20000
# weighted avg       0.84      0.84      0.84     20000
#
# [[9080  920]
#  [2341 7659]]

# %%
y_train_pred = model.predict(X_train, verbose=1)
y_train_probs = model.predict_proba(X_train, verbose=1) # to predict probability
target_names = list(tdf.phishing.astype('category').cat.categories)
target_names = [str(t) for t in target_names]
print(classification_report(y_train, y_train_pred, target_names=target_names))
print(confusion_matrix(y_train, y_train_pred))
# Out:
# 80000/80000 [==============================] - 106s 1ms/step
# 80000/80000 [==============================] - 106s 1ms/step
#               precision    recall  f1-score   support
#
#        False       0.82      0.94      0.88     40000
#         True       0.93      0.80      0.86     40000
#
#     accuracy                           0.87     80000
#    macro avg       0.88      0.87      0.87     80000
# weighted avg       0.88      0.87      0.87     80000
#
# [[37633  2367]
#  [ 8014 31986]]

# %% [markdown]
# ## Save model

# %% [raw]
# model.save('./models/phish_cat_lstm_2017.h5')

# %% [raw]
# words_df = pd.DataFrame(words_list, columns=['vocab'])
# words_df.to_csv('./models/phish_cat_vocab_2017.csv', index=False, encoding='utf-8')
