# %%
from __future__ import print_function

import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

import tldextract


def url2domain(url, exclude_subdomains=False):
    """Extract the domain from URL.
    """
    tld = tldextract.extract(url)
    a = []
    if tld.subdomain != '':
        if isinstance(exclude_subdomains, list):
            if tld.subdomain not in exclude_subdomains:
                a.append(tld.subdomain)
        elif not exclude_subdomains :
            a.append(tld.subdomain)
    a.append(tld.domain)
    if tld.suffix != '':
        a.append(tld.suffix)
    domain = '.'.join(a)
    return domain


NGRAMS = 2
FEATURE_LEN = 128
EPOCHS = 15
SAMPLES = 50000

df = pd.read_csv('./data/phishtank_2017.csv.bz2')
df.dropna(subset=['domain'], inplace=True)
df['domain'] = df.domain.apply(lambda c: url2domain(c, exclude_subdomains=['www']))
df
# Out:
#              ID                                          Phish URL  \
# 0       4717300  http://g28.ycxafz.biz/added on Jan 1st 2017 6:...
# 1       4717281  http://sistemas.miranda.gob.ve/1/Sign%20on/add...
# 2       4717246  http://sheehydaringproject.com/PDFILES/added o...
# 3       4717232  http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       4717222  http://www.w-reia.com/bremer/new.php?cmd=login...
# 5       4717219  http://fm.registrovotorantim.com.br/.connect.h...
# 6       4717215  http://etiissallat.bugs3.com/Alibaba/alibaba/a...
# 7       4717170  http://iniciasecion4.webcindario.com/app/faceb...
# 8       4717169  http://collectsuccess.com.au/language/CD/CD/in...
# 9       4717161  http://www.vaastumahajeevan.com/TT/Submit/Offi...
# 10      4717158  http://frankworldsports.com/Signtitle/MND/inde...
# 11      4717156  http://dropboxphotosfile.96.lt/Newdropbox15/dr...
# 12      4717151  http://bholawoolindustries.com/data/data/index...
# 13      4717146  http://stevesautobodyandpaint.com/cgi-bin/scam...
# 14      4717141  http://wellsfargo-online19.890m.com/online/ban...
# 15      4717131  http://kanoasfloripa.com.br/drokeycrewrti/2f44...
# 16      4717101  http://adsinfengering-departs-info07.16mb.com/...
# 17      4717093  http://sendmypacket.com/c16/added on Dec 31st ...
# 18      4717036  https://loading-please-wait-thank-you.blogspot...
# 19      4717021  http://uniplastica.pt/libraries/tcpdf/config/A...
# 20      4717645  http://www.aarcadigital.com/images/themes/mail...
# 21      4717642  http://ipcamerabandung.com/101/Gdoc/added on J...
# 22      4717582  http://pietromauro.com/added on Jan 1st 2017 1...
# 23      4717535  http://demaror.ro/errors/login.alibaba.com/log...
# 24      4717528  http://ehoplus.ru/blocks/cgi-bin/resolution-ce...
# 25      4717508  http://agtecnlogy.com/cpst/added on Jan 1st 20...
# 26      4717507  http://advancedclean.biz/onze/start.phpadded o...
# 27      4717498  http://mozaikfoodinovation.co.id/cgi_bin/all/e...
# 28      4717492  http://collectorly.com/language/fr-FR/logo/err...
# 29      4717485  http://dochoixehoiquangbinh.com/cu.edu/added o...
# ...         ...                                                ...
# 101290  5407453  http://online-banking.mobile.go.mambanetworkso...
# 101291  5407450  http://www.royalbankpacific.com/wp-admin/maint...
# 101292  5407449  http://settings-pro.000webhostapp.com/Payment-...
# 101293  5407446  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101294  5407445  http://egamandala0031.000webhostapp.com/bayar/...
# 101295  5407429  http://recoveracct881557.000webhostapp.com/pay...
# 101296  5407426  http://namphuong-tn.vn/wp-content/languages/th...
# 101297  5407425  http://namphuong-tn.vn/wp-content/languages/th...
# 101298  5407399  http://lionsgateglass.com/node/info.php?amp=&c...
# 101299  5407394  https://sukalah.000webhostapp.com/recovery-ans...
# 101300  5407544  http://camplakefire.com.au/include/chase-onlin...
# 101301  5407543  http://assemblgroup.com/ww/8eef918ed75a259d0e3...
# 101302  5407541  http://www.drzwikurtysiak.pl/plugins/content/p...
# 101303  5407540  http://rererara733.000webhostapp.com/publick/r...
# 101304  5407533  http://service-settings.000webhostapp.com/Paym...
# 101305  5407531  http://recoverme002211.000webhostapp.com/payme...
# 101306  5407529  http://online-banking.mobile.go.mambanetworkso...
# 101307  5407528  http://online-banking.mobile.go.mambanetworkso...
# 101308  5407527  http://online-banking.mobile.go.mambanetworkso...
# 101309  5407526  http://online-banking.mobile.go.mambanetworkso...
# 101310  5407525  http://ve-protect002.000webhostapp.com/payment...
# 101311  5407524  http://ve-protect002.000webhostapp.com/payment...
# 101312  5407521  http://vip01-secure.000webhostapp.com/payment-...
# 101313  5407516  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101314  5407515  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101315  5407512  http://posari.com/Goody/Yahoo/home/index.phpad...
# 101316  5407505  http://abrazzak.com/login.php?cmd=login_submit...
# 101317  5407493  http://khanqahzakariya.lk/wpadmin/ex2017/login...
# 101318  5407490  http://pegesunblocking.000webhostapp.com/bayar...
# 101319  5407489  http://pegesunblocking.000webhostapp.com/bayar...
#
#                Submitted       Valid?  Online?  \
# 0             by cleanmx  VALID PHISH  Offline
# 1             by cleanmx  VALID PHISH  Offline
# 2             by cleanmx  VALID PHISH  Offline
# 3             by cleanmx  VALID PHISH  Offline
# 4             by cleanmx  VALID PHISH  Offline
# 5             by cleanmx  VALID PHISH   ONLINE
# 6             by cleanmx  VALID PHISH  Offline
# 7            by prebytes  VALID PHISH  Offline
# 8            by prebytes  VALID PHISH  Offline
# 9            by prebytes  VALID PHISH  Offline
# 10           by prebytes  VALID PHISH  Offline
# 11           by prebytes  VALID PHISH  Offline
# 12           by prebytes  VALID PHISH  Offline
# 13           by prebytes  VALID PHISH  Offline
# 14           by prebytes  VALID PHISH  Offline
# 15           by prebytes  VALID PHISH  Offline
# 16           by leofelix  VALID PHISH  Offline
# 17            by cleanmx  VALID PHISH  Offline
# 18      by PhishReporter  VALID PHISH  Offline
# 19            by cleanmx  VALID PHISH  Offline
# 20            by cleanmx  VALID PHISH  Offline
# 21            by cleanmx  VALID PHISH  Offline
# 22            by cleanmx  VALID PHISH  Offline
# 23            by cleanmx  VALID PHISH   ONLINE
# 24      by PhishReporter  VALID PHISH  Offline
# 25            by cleanmx  VALID PHISH  Offline
# 26            by cleanmx  VALID PHISH  Offline
# 27            by cleanmx  VALID PHISH  Offline
# 28            by cleanmx  VALID PHISH  Offline
# 29            by cleanmx  VALID PHISH  Offline
# ...                  ...          ...      ...
# 101290        by cleanmx  VALID PHISH  Offline
# 101291        by cleanmx  VALID PHISH  Offline
# 101292        by cleanmx  VALID PHISH  Offline
# 101293        by cleanmx  VALID PHISH  Offline
# 101294        by cleanmx  VALID PHISH  Offline
# 101295        by cleanmx  VALID PHISH  Offline
# 101296        by cleanmx  VALID PHISH  Offline
# 101297        by cleanmx  VALID PHISH  Offline
# 101298        by cleanmx  VALID PHISH  Offline
# 101299        by cleanmx  VALID PHISH  Offline
# 101300        by cleanmx  VALID PHISH  Offline
# 101301        by cleanmx  VALID PHISH  Offline
# 101302        by cleanmx  VALID PHISH  Offline
# 101303        by cleanmx  VALID PHISH   ONLINE
# 101304        by cleanmx  VALID PHISH   ONLINE
# 101305        by cleanmx  VALID PHISH   ONLINE
# 101306        by cleanmx  VALID PHISH  Offline
# 101307        by cleanmx  VALID PHISH  Offline
# 101308        by cleanmx  VALID PHISH  Offline
# 101309        by cleanmx  VALID PHISH  Offline
# 101310        by cleanmx  VALID PHISH  Offline
# 101311        by cleanmx  VALID PHISH  Offline
# 101312        by cleanmx  VALID PHISH   ONLINE
# 101313        by cleanmx  VALID PHISH  Offline
# 101314        by cleanmx  VALID PHISH  Offline
# 101315        by cleanmx  VALID PHISH  Offline
# 101316        by cleanmx  VALID PHISH   ONLINE
# 101317        by cleanmx  VALID PHISH   ONLINE
# 101318        by cleanmx  VALID PHISH  Offline
# 101319        by cleanmx  VALID PHISH  Offline
#
#                                                       url  \
# 0                                  http://g28.ycxafz.biz/
# 1             http://sistemas.miranda.gob.ve/1/Sign%20on/
# 2                 http://sheehydaringproject.com/PDFILES/
# 3       http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       http://www.w-reia.com/bremer/new.php?cmd=login...
# 5       http://fm.registrovotorantim.com.br/.connect.html
# 6       http://etiissallat.bugs3.com/Alibaba/alibaba/a...
# 7       http://iniciasecion4.webcindario.com/app/faceb...
# 8       http://collectsuccess.com.au/language/CD/CD/in...
# 9       http://www.vaastumahajeevan.com/TT/Submit/Offi...
# 10      http://frankworldsports.com/Signtitle/MND/inde...
# 11      http://dropboxphotosfile.96.lt/Newdropbox15/dr...
# 12      http://bholawoolindustries.com/data/data/index...
# 13      http://stevesautobodyandpaint.com/cgi-bin/scam...
# 14      http://wellsfargo-online19.890m.com/online/ban...
# 15      http://kanoasfloripa.com.br/drokeycrewrti/2f44...
# 16      http://adsinfengering-departs-info07.16mb.com/...
# 17                           http://sendmypacket.com/c16/
# 18      https://loading-please-wait-thank-you.blogspot...
# 19      http://uniplastica.pt/libraries/tcpdf/config/A...
# 20      http://www.aarcadigital.com/images/themes/mail...
# 21                   http://ipcamerabandung.com/101/Gdoc/
# 22                                http://pietromauro.com/
# 23      http://demaror.ro/errors/login.alibaba.com/log...
# 24      http://ehoplus.ru/blocks/cgi-bin/resolution-ce...
# 25                            http://agtecnlogy.com/cpst/
# 26                http://advancedclean.biz/onze/start.php
# 27      http://mozaikfoodinovation.co.id/cgi_bin/all/e...
# 28      http://collectorly.com/language/fr-FR/logo/err...
# 29                http://dochoixehoiquangbinh.com/cu.edu/
# ...                                                   ...
# 101290  http://online-banking.mobile.go.mambanetworkso...
# 101291  http://www.royalbankpacific.com/wp-admin/maint...
# 101292  http://settings-pro.000webhostapp.com/Payment-...
# 101293  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 
# 101274  5407327  https://sukalah.000webhostapp.com/recovery-che...
# 101277  5407309  http://application-id025974-secure.mountzionin...
# 101279  5407304  http://dropbox.com-login.asyouwishservices.com...
# 101285  5407474  http://mattchhmatch.eu5.netadded on Jan 1st 20...
# 101286  5407468  http://mjvo.com/wp-admin/drop/DropNewVasion/Fr...
# 101289  5407454  http://online-banking.mobile.go.mambanetworkso...
# 101291  5407450  http://www.royalbankpacific.com/wp-admin/maint...
# 101293  5407446  http://healthyidealroutine.com/fl/87fb6e7a8551...
# 101300  5407544  http://camplakefire.com.au/include/chase-onlin...
# 101301  5407543  http://assemblgroup.com/ww/8eef918ed75a259d0e3...
#
#                Submitted       Valid?  Online?  \
# 0             by cleanmx  VALID PHISH  Offline
# 1             by cleanmx  VALID PHISH  Offline
# 2             by cleanmx  VALID PHISH  Offline
# 3             by cleanmx  VALID PHISH  Offline
# 4             by cleanmx  VALID PHISH  Offline
# 5             by cleanmx  VALID PHISH   ONLINE
# 6             by cleanmx  VALID PHISH  Offline
# 7            by prebytes  VALID PHISH  Offline
# 8            by prebytes  VALID PHISH  Offline
# 9            by prebytes  VALID PHISH  Offline
# 10           by prebytes  VALID PHISH  Offline
# 11           by prebytes  VALID PHISH  Offline
# 12           by prebytes  VALID PHISH  Offline
# 13           by prebytes  VALID PHISH  Offline
# 14           by prebytes  VALID PHISH  Offline
# 15           by prebytes  VALID PHISH  Offline
# 16           by leofelix  VALID PHISH  Offline
# 17            by cleanmx  VALID PHISH  Offline
# 18      by PhishReporter  VALID PHISH  Offline
# 19            by cleanmx  VALID PHISH  Offline
# 20            by cleanmx  VALID PHISH  Offline
# 21            by cleanmx  VALID PHISH  Offline
# 22            by cleanmx  VALID PHISH  Offline
# 23            by cleanmx  VALID PHISH   ONLINE
# 24      by PhishReporter  VALID PHISH  Offline
# 25            by cleanmx  VALID PHISH  Offline
# 26            by cleanmx  VALID PHISH  Offline
# 27            by cleanmx  VALID PHISH  Offline
# 28            by cleanmx  VALID PHISH  Offline
# 29            by cleanmx  VALID PHISH  Offline
# ...                  ...          ...      ...
# 101209     by crazymikey  VALID PHISH  Offline
# 101213        by cleanmx  VALID PHISH  Offline
# 101223  by PhishReporter  VALID PHISH  Offline
# 101235       by leofelix  VALID PHISH  Offline
# 101236  by PhishReporter  VALID PHISH  Offline
# 101237        by cleanmx  VALID PHISH   ONLINE
# 101238        by cleanmx  VALID PHISH  Offline
# 101245       by leofelix  VALID PHISH  Offline
# 101247        by cleanmx  VALID PHISH  Offline
# 101250        by cleanmx  VALID PHISH  Offline
# 101251        by cleanmx  VALID PHISH  Offline
# 101256        by cleanmx  VALID PHISH  Offline
# 101257       by leofelix  VALID PHISH  Offline
# 101258       by leofelix  VALID PHISH  Offline
# 101259       by leofelix  VALID PHISH  Offline
# 101260        by cleanmx  VALID PHISH  Offline
# 101265       by leofelix  VALID PHISH  Offline
# 101267        by cleanmx  VALID PHISH  Offline
# 101268        by cleanmx  VALID PHISH  Offline
# 101271        by cleanmx  VALID PHISH   ONLINE
# 101274       by leofelix  VALID PHISH  Offline
# 101277  by PhishReporter  VALID PHISH  Offline
# 101279        by cleanmx  VALID PHISH  Offline
# 101285  by mahendrasingh  VALID PHISH  Offline
# 101286        by cleanmx  VALID PHISH   ONLINE
# 101289        by cleanmx  VALID PHISH  Offline
# 101291        by cleanmx  VALID PHISH  Offline
# 101293        by cleanmx  VALID PHISH  Offline
# 101300        by cleanmx  VALID PHISH  Offline
# 101301        by cleanmx  VALID PHISH  Offline
#
#                                                       url  \
# 0                                  http://g28.ycxafz.biz/
# 1             http://sistemas.miranda.gob.ve/1/Sign%20on/
# 2                 http://sheehydaringproject.com/PDFILES/
# 3       http://monar-kielce.pl/templates/beez/gdoc/ind...
# 4       http://www.w-reia.com/bremer/new.php?cmd=login...
# 5       http://fm.registrovotorantim.com.br/.connect.html
# 6       http://etiissallat.bugs3.com/Alibaba/alibaba/a...
# 7       http://iniciasecion4.webcindario.com/app/faceb...
# 8       http://collectsuccess.com.au/language/CD/CD/in...
# 9       http://www.vaastumahajeevan.com/TT/Submit/Offi...
# 10      http://frankworldsports.com/Signtitle/MND/inde...
# 11      http://dropboxphotosfile.96.lt/Newdropbox15/dr...
# 12      http://bholawoolindustries.com/data/data/index...
# 13      http://stevesautobodyandpaint.com/cgi-bin/scam...
# 14      http://wellsfargo-online19.890m.com/online/ban...
# 15      http://kanoasfloripa.com.br/drokeycrewrti/2f44...
# 16      http://adsinfengering-departs-info07.16mb.com/...
# 17                           http://sendmypacket.com/c16/
# 18      https://loading-please-wait-thank-you.blogspot...
# 19      http://uniplastica.pt/libraries/tcpdf/config/A...
# 20      http://www.aarcadigital.com/images/themes/mail...
# 21                   http://ipcamerabandung.com/101/Gdoc/
# 22                                http://pietromauro.com/
# 23      http://demaror.ro/errors/login.alibaba.com/log...
# 24      http://ehoplus.ru/blocks/cgi-bin/resolution-ce...
# 25                            http://agtecnlogy.com/cpst/
# 26                http://advancedclean.biz/onze/start.php
# 27      http://mozaikfoodinovation.co.id/cgi_bin/all/e...
# 28      http://collectorly.com/language/fr-FR/logo/err...
# 29                http://dochoixehoiquangbinh.com/cu.edu/
# ...                                                   ...
# 101209         http://venditacaldaieroma.com/aol.netflix/
# 101213  http://universaldrivingschoolnj.com/js/css/wel...
# 101223  https://www.buyiteasy.in/Account/jhkyty=/signi...
# 101235   https://securevip01.000webhostapp.com/index.html
# 101236  http://softica.fr/logs/eror/accountID/www.Weba...
# 101237  http://importarmas.com/modules/mod_feed/Alibab...
# 101238                   http://paturnie.com/service-inc/
# 101245  https://pegesunblocking.000webhostapp.com/baya...
# 101247                        http://59.ip-145-239-86.eu/
# 101250  http://rgvcupcakefactory.com/wells/riusa/well/...
# 101251  http://productosdemaratierra.com/identificatio...
# 101256  http://martintechscientific.com.ng/worldbestes...
# 101257  https://tyrannicidal-access.000webhostapp.com/...
# 101258           http://feedbackhere.atspace.cc/login.php
# 101259       http://www.updatefbs-1klp.at.ua/iFOTZEM2sec/
# 101237  2017-12-31 20:35:00                                    importarmas.com
# 101238  2017-12-31 20:11:00                                       paturnie.com
# 101245  2017-12-31 23:43:00                  pegesunblocking.000webhostapp.com
# 101247  2017-12-31 22:42:00                                59.ip-145-239-86.eu
# 101250  2017-12-31 22:42:00                              rgvcupcakefactory.com
# 101251  2017-12-31 22:42:00                          productosdemaratierra.com
# 101256  2017-12-31 22:41:00                        martintechscientific.com.ng
# 101257  2017-12-31 22:27:00              tyrannicidal-access.000webhostapp.com
# 101258  2017-12-31 22:00:00                            feedbackhere.atspace.cc
# 101259  2017-12-31 21:59:00                           www.updatefbs-1klp.at.ua
# 101260  2018-01-01 02:41:00                    ve-protect002.000webhostapp.com
# 101265  2018-01-01 01:12:00                               register-pagees22.gq
# 101267  2018-01-01 01:11:00                                  bankofamerieca.cf
# 101268  2018-01-01 01:10:00                   egamandala0031.000webhostapp.com
# 101271  2018-01-01 01:10:00                      webmailmail.000webhostapp.com
# 101274  2018-01-01 00:53:00                          sukalah.000webhostapp.com
# 101277  2018-01-01 00:21:00  application-id025974-secure.mountzionint.download
# 101279  2018-01-01 00:05:00            dropbox.com-login.asyouwishservices.com
# 101285  2018-01-01 05:16:00                               mattchhmatch.eu5.net
# 101286  2018-01-01 04:42:00                                           mjvo.com
# 101289  2018-01-01 04:41:00  online-banking.mobile.go.mambanetworksolutions...
# 101291  2018-01-01 04:40:00                               royalbankpacific.com
# 101293  2018-01-01 04:40:00                            healthyidealroutine.com
# 101300  2018-01-01 07:10:00                                camplakefire.com.au
# 101301  2018-01-01 07:10:00                                   assemblgroup.com
#
# [52785 rows x 8 columns]

# %%
try:
    sdf.groupby('target').agg({'domain': 'count'})
except:
    pass

# %%
adf = pd.read_csv('./data/top-1m.csv.zip', header=None)
adf.columns = ['rank', 'domain']
adf
# Out:
#            rank                        domain
# 0             1                    google.com
# 1             2                   youtube.com
# 2             3                  facebook.com
# 3             4                     baidu.com
# 4             5                 wikipedia.org
# 5             6                     yahoo.com
# 6             7                  google.co.in
# 7             8                    reddit.com
# 8             9                        qq.com
# 9            10                    taobao.com
# 10           11                    amazon.com
# 11           12                   twitter.com
# 12           13                  google.co.jp
# 13           14                     tmall.com
# 14           15                      live.com
# 15           16                        vk.com
# 16           17                      sohu.com
# 17           18                 instagram.com
# 18           19                   sina.com.cn
# 19           20                        jd.com
# 20           21                     weibo.com
# 21           22                        360.cn
# 22           23                     google.de
# 23           24                  google.co.uk
# 24           25                 google.com.br
# 25           26                     google.fr
# 26           27                  linkedin.com
# 27           28                     google.ru
# 28           29                list.tmall.com
# 29           30                 google.com.hk
# ...         ...                           ...
# 999970   999971              bestofriyadh.com
# 999971   999972                        z0x.us
# 999972   999973       diariodosudoeste.com.br
# 999973   999974               paranapesca.com
# 999974   999975                        ne2.ca
# 999975   999976                    refleqt.ro
# 999976   999977          larrymillerdodge.com
# 999977   999978              mcguinnhomes.com
# 999978   999979  overwatchaccuracy.weebly.com
# 999979   999980                     logon.now
# 999980   999981       bromofratguy.tumblr.com
# 999981   999982             transtempo.com.ua
# 999982   999983                      yira.org
# 999983   999984                        t-s.fr
# 999984   999985                ebook-site.com
# 999985   999986                      kpft.org
# 999986   999987             hexxitservers.com
# 999987   999988     circulodeespecialistas.cl
# 999988   999989             ecomparedeals.com
# 999989   999990                  yggdrasil.pl
# 999990   999991               sexhaustion.com
# 999991   999992     liveuis-my.sharepoint.com
# 999992   999993          dadsdollarsdebts.com
# 999993   999994              bwahahacomics.ru
# 999994   999995   providentpersonalcredit.com
# 999995   999996           liberty-shopping.us
# 999996   999997                       uazz.pl
# 999997   999998                 waltonsun.com
# 999998   999999                      aspvv.it
# 999999  1000000                wetterklima.de
#
# [1000000 rows x 2 columns]

# %%
ldf = adf[['domain']].head(SAMPLES)
pdf = sdf[['domain']].sample(SAMPLES, random_state=21)

# %%
ldf['phishing'] = False
pdf['phishing'] = True
tdf = pd.concat([ldf, pdf])
tdf
# Out:
#                                                   domain  phishing
# 0                                             google.com     False
# 1                                            youtube.com     False
# 2                                           facebook.com     False
# 3                                              baidu.com     False
# 4                                          wikipedia.org     False
# 5                                              yahoo.com     False
# 6                                           google.co.in     False
# 7                                             reddit.com     False
# 8                                                 qq.com     False
# 9                                             taobao.com     False
# 10                                            amazon.com     False
# 11                                           twitter.com     False
# 12                                          google.co.jp     False
# 13                                             tmall.com     False
# 14                                              live.com     False
# 15                                                vk.com     False
# 16                                              sohu.com     False
# 17                                         instagram.com     False
# 18                                           sina.com.cn     False
# 19                                                jd.com     False
# 20                                             weibo.com     False
# 21                                                360.cn     False
# 22                                             google.de     False
# 23                                          google.co.uk     False
# 24                                         google.com.br     False
# 25                                             google.fr     False
# 26                                          linkedin.com     False
# 27                                             google.ru     False
# 28                                        list.tmall.com     False
# 29                                         google.com.hk     False
# ...                                                  ...       ...
# 24815                              bloked-centers.my1.ru      True
# 8804                                       200.220.179.4      True
# 70510  apple.id.info-reminder.site.apple.id.info-remi...      True
# 86662                       freder6654.000webhostapp.com      True
# 57284                               setting-info.clan.la      True
# 59847                                    tbs-services.fr      True
# 21602                                     iitauditor.com      True
# 40046                                 confirmadebitos.tk      True
# 94283                              levelacommodities.com      True
# 75390                                nivanspromoters.com      True
# 25363                                        epapers.biz      True
# 74521                           migratingmailbox.ukit.me      True
# 77745                        bocpzonasegura.vjabcpweb.tk      True
# 29579                               premiumsuites.com.bo      True
# 28127                                            tbd.lat      True
# 820                                         imifaloda.hu      True
# 74840                        nethdflix.azurewebsites.net      True
# 30966                                   judsonpalmer.com      True
# 29227                             performancebilisim.com      True
# 38201     validate-storagequota-helpdesk.myfreesites.net      True
# 31399                                   fastertechno.com      True
# 87335                                 speakershack.co.uk      True
# 37599                                     tornado.com.pk      True
# 83798                                adidastaiwan.com.tw      True
# 88885                                  rikvinbiotech.com      True
# 56925                                        emceedz.com      True
# 50982                                    get-info.my1.ru      True
# 88610                     santander.moduloempresarial.ml      True
# 34105                                   quality2west.com      True
# 3007                                japonesdaagua.com.br      True
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Preprocessing the input data

# %%
# build n-gram list
vect = CountVectorizer(analyzer='char', max_df=0.3, min_df=3, ngram_range=(NGRAMS, NGRAMS), lowercase=False) 
#vect = CountVectorizer(analyzer='char', ngram_range=(NGRAMS, NGRAMS), lowercase=False) 
a = vect.fit_transform(tdf.domain)
vocab = vect.vocabulary_

# sort n-gram by freq (highest -> lowest)
words = []
for b in vocab:
    c = vocab[b]
    #print(b, c, a[:, c].sum())
    words.append((a[:, c].sum(), b))
    #break
words = sorted(words, reverse=True)
words_list = [w[1] for w in words]
num_words = len(words_list)
print("num_words = %d" % num_words)


def find_ngrams(text, n):
    a = zip(*[text[i:] for i in range(n)])
    wi = []
    for i in a:
        w = ''.join(i)
        try:
            idx = words_list.index(w)
        except:
            idx = 0
        wi.append(idx)
    return wi

# build X from index of n-gram sequence
X = np.array(tdf.domain.apply(lambda c: find_ngrams(c, NGRAMS)))
X
# Out:
# num_words = 1464
# array([list([124, 100, 129, 312, 38, 6, 0, 0, 0]),
#        list([290, 66, 140, 165, 214, 122, 6, 0, 0, 0]),
#        list([186, 37, 62, 56, 159, 100, 215, 139, 0, 0, 0]), ...,
#        list([82, 7, 18, 15, 7, 76, 32, 2, 60, 144, 103, 176, 180, 198, 57, 385, 108, 210, 107, 9, 1, 82, 13, 31, 80, 14, 61, 144, 406]),
#        list([304, 207, 14, 21, 28, 188, 811, 1169, 58, 1, 11, 23, 0, 0, 0]),
#        list([288, 45, 53, 8, 4, 1, 344, 88, 331, 127, 229, 207, 27, 0, 0, 0, 19, 73, 96])],
#       dtype=object)

# %%
# check max/avg feature
X_len = []
for x in X:
    X_len.append(len(x))

max_feature_len = max(X_len)
avg_feature_len = int(np.mean(X_len))

print("Max feature len = %d, Avg. feature len = %d" % (max_feature_len, avg_feature_len))
# Out:
# Max feature len = 62, Avg. feature len = 15

# %%
y = np.array(tdf.phishing.astype('category').cat.codes)

# Split train and test dataset
X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %% [markdown]
# ## Train a LSTM model

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, Activation
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import load_model

max_features = num_words # 20000
feature_len = FEATURE_LEN # avg_feature_len # cut texts after this number of words (among top max_features most common words)
batch_size = 32

print(len(X_train), 'train sequences')
print(len(X_test), 'test sequences')

print('Pad sequences (samples x time)')
X_train = sequence.pad_sequences(X_train, maxlen=feature_len)
X_test = sequence.pad_sequences(X_test, maxlen=feature_len)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)

num_classes = np.max(y_train) + 1
print(num_classes, 'classes')

print('Convert class vector to binary class matrix '
      '(for use with categorical_crossentropy)')
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# /opt/venv/local/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 80000 train sequences
# 20000 test sequences
# Pad sequences (samples x time)
# X_train shape: (80000, 128)
# X_test shape: (20000, 128)
# 2 classes
# Convert class vector to binary class matrix (for use with categorical_crossentropy)
# y_train shape: (80000, 2)
# y_test shape: (20000, 2)

# %%
print('Build model...')

model = Sequential()
model.add(Embedding(num_words, 32, input_length=feature_len))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(num_classes, activation='softmax'))

# try using different optimizers and different optimizer configs
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 128, 32)           46848
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 129,538
# Trainable params: 129,538
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print('Train...')
model.fit(X_train, y_train, batch_size=batch_size, epochs=EPOCHS,
          validation_split=0.1, verbose=2)
score, acc = model.evaluate(X_test, y_test,
                            batch_size=batch_size, verbose=2)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Train...
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/15
#  - 565s - loss: 0.4667 - acc: 0.7718 - val_loss: 0.4319 - val_acc: 0.7883
# Epoch 2/15
#  - 550s - loss: 0.4311 - acc: 0.7917 - val_loss: 0.4207 - val_acc: 0.7989
# Epoch 3/15
#  - 539s - loss: 0.4201 - acc: 0.7970 - val_loss: 0.4203 - val_acc: 0.7910
# Epoch 4/15
#  - 557s - loss: 0.4112 - acc: 0.8028 - val_loss: 0.4156 - val_acc: 0.8009
# Epoch 5/15
#  - 546s - loss: 0.4044 - acc: 0.8054 - val_loss: 0.4235 - val_acc: 0.7963
# Epoch 6/15
#  - 542s - loss: 0.3974 - acc: 0.8083 - val_loss: 0.4121 - val_acc: 0.8039
# Epoch 7/15
#  - 560s - loss: 0.3917 - acc: 0.8115 - val_loss: 0.4199 - val_acc: 0.7990
# Epoch 8/15
#  - 549s - loss: 0.3865 - acc: 0.8151 - val_loss: 0.4119 - val_acc: 0.8011
# Epoch 9/15
#  - 553s - loss: 0.3823 - acc: 0.8166 - val_loss: 0.4138 - val_acc: 0.8003
# Epoch 10/15
#  - 552s - loss: 0.3761 - acc: 0.8203 - val_loss: 0.4086 - val_acc: 0.8115
# Epoch 11/15
#  - 526s - loss: 0.3721 - acc: 0.8229 - val_loss: 0.4139 - val_acc: 0.8107
# Epoch 12/15
#  - 515s - loss: 0.3668 - acc: 0.8256 - val_loss: 0.4205 - val_acc: 0.8016
# Epoch 13/15
#  - 521s - loss: 0.3626 - acc: 0.8287 - val_loss: 0.4192 - val_acc: 0.8064
# Epoch 14/15
#  - 523s - loss: 0.3586 - acc: 0.8308 - val_loss: 0.4217 - val_acc: 0.8045
# Epoch 15/15
#  - 522s - loss: 0.3541 - acc: 0.8319 - val_loss: 0.4187 - val_acc: 0.8106
# Test score: 0.42821635913848877
# Test accuracy: 0.79985

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred = model.predict_classes(X_test, verbose=2)
p = model.predict_proba(X_test, verbose=2) # to predict probability
target_names = list(tdf.phishing.astype('category').cat.categories)

# %%
target_names = [str(t) for t in target_names]
print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names))
print(confusion_matrix(np.argmax(y_test, axis=1), y_pred))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.78      0.84      0.81     10000
#        True       0.83      0.76      0.79     10000
#
# avg / total       0.80      0.80      0.80     20000
#
# [[8429 1571]
#  [2432 7568]]

# %% [markdown]
# ## Save model

# %%
model.save('./models/phish_cat_lstm_2017.h5')

# %%
words_df = pd.DataFrame(words_list, columns=['vocab'])
words_df.to_csv('./models/phish_cat_vocab_2017.csv', index=False, encoding='utf-8')
